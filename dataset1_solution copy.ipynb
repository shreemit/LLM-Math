# %%
import openai
from datasets import load_dataset
from openai import OpenAI
from tqdm import tqdm
import pandas as pd 
from dotenv import load_dotenv
import os

load_dotenv()

import pathlib
import textwrap

import google.generativeai as genai

# %%
# Loading the dataset
dataset  = pd.read_csv('math_operations.csv')

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

# %%
"""ChatGPT completion"""
import os
def chatgpt_completion(prompt_text):
    genai.configure(api_key=GOOGLE_API_KEY)
    prompt = "GIVE ME ONLY THE RESULT " + prompt_text
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content(prompt)
    return response.text


def evaluate(results, answers):
    accs = []
    for result, answer in zip(results, answers):
        try:
            _ = float(result)
            # print(float(result), float(answer))
            if float(result) == float(answer):
                accs.append(1)
            else:
                accs.append(0)
        except:
            accs.append(0)

    print("The scores on the test set: ", sum(accs)/len(accs)) # around 38% - 50%
    return

# %%
chatgpt_completion("242345 + 51233")
# Out:
# '293578'

# %%
def evaluate_single(result, answer):
    try:
        _ = float(result)
        # print(float(result), float(answer))
        if float(result) == float(answer):
            return 1
        else:
            return 0
    except:
        return 0

# %%
import time

# time to restrict query speed
class SpeedLimitTimer:
    def __init__(self, second_per_step=3.1):
        self.record_time = time.time()
        self.second_per_step = second_per_step

    def step(self):
        time_div = time.time() - self.record_time
        if time_div <= self.second_per_step:
            time.sleep(self.second_per_step - time_div)
        self.record_time = time.time()

    def sleep(self, s):
        time.sleep(s)


timer = SpeedLimitTimer(second_per_step=3.1)

# %%
def parse_zeroshot_chatgpt_output(chatgpt_output):
    # Follow Toolformer 
    # https://arxiv.org/abs/2302.04761
    # Zero-Shot Math Reasoning with ChatGPT     
    # Check for the first number predicted by the model. 
    # An exception to this is if the model’s prediction contains an equation (e.g., “The correct answer is 5+3=8”), in which case we consider the first number after the “=” sign to be its prediction.
    def is_number(s):
        try:
            float(s)
            return True
        except ValueError:
            return False
    if "=" in chatgpt_output:
        chatgpt_output = chatgpt_output.split("=")[1]

    words = chatgpt_output.split()
    for word in words:
        if is_number(word):
            return word
    return float("inf")  # Return inf if no number word is found

data_list = []
def zero_shot_prompt_chatgpt(test_dataset):
    # data_list = []
    for idx, data in tqdm(test_dataset.iterrows()):
        context = "GIVE ME ONLY THE RESULT IN ONE WORD"  
        question = data["Operation"] 
        answer = data["Result"]
        operator = data["Operator"] 
        num_Digits = data["Num_Digits"]

        example_prompt =  context + " " + question 
        try:
            chatgpt_output = chatgpt_completion(example_prompt)
            result = parse_zeroshot_chatgpt_output(chatgpt_output)
        except Exception as e:
            print(f"An error occurred: {e}")
            result = None

        correct = evaluate_single(result, answer)

        data_list.append({
            'Question': question,
            'Answer': answer,
            'Operator': operator,
            'Num_Digits': num_Digits,
            'Predicted': result,
            'Correct': correct
        })
        timer.step()

    df = pd.DataFrame(data_list)
    return df

# %%
data_list
# Out:
# [{'Question': 'give me the addition of 6772 and 2099',
#   'Answer': 8871.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8871',
#   'Correct': 1},
#  {'Question': 'what is 3368 - 8917',
#   'Answer': -5549.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-5549',
#   'Correct': 1},
#  {'Question': 'give me the quotient of 6509 and 4865',
#   'Answer': 1.33792394655704,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'calculate 6322 - 7087',
#   'Answer': -765.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-765',
#   'Correct': 1},
#  {'Question': '2532 times 2501',
#   'Answer': 6332532.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 8441 divided by 3744',
#   'Answer': 2.2545405982905984,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '2',
#   'Correct': 0},
#  {'Question': 'what is 6420 plus 6646',
#   'Answer': 13066.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '13066',
#   'Correct': 1},
#  {'Question': 'calculate 7455 + 6675',
#   'Answer': 14130.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '14130',
#   'Correct': 1},
#  {'Question': 'tell me 3784 minus 8857',
#   'Answer': -5073.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-5073',
#   'Correct': 1},
#  {'Question': 'what is the addition of 8561 + 6934',
#   'Answer': 15495.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '15495',
#   'Correct': 1},
#  {'Question': 'give me the quotient of 8401 and 4878',
#   'Answer': 1.7222222222222223,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.72',
#   'Correct': 0},
#  {'Question': 'what is the division of 3357 / 6712',
#   'Answer': 0.5001489868891538,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.5',
#   'Correct': 0},
#  {'Question': 'calculate 9123 - 5553',
#   'Answer': 3570.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '3570',
#   'Correct': 1},
#  {'Question': 'what is 6882 divided by 6682',
#   'Answer': 1.0299311583358275,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'tell me 2086 minus 5557',
#   'Answer': -3471.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-3471',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 5634 - 3026',
#   'Answer': 2608.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '2608',
#   'Correct': 1},
#  {'Question': 'what is the division of 8913 / 6317',
#   'Answer': 1.410954567041317,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.412',
#   'Correct': 0},
#  {'Question': '8912 - 2879',
#   'Answer': 6033.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '6033',
#   'Correct': 1},
#  {'Question': 'what is 6894 - 2922',
#   'Answer': 3972.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '3972',
#   'Correct': 1},
#  {'Question': 'what is 3059 - 7651',
#   'Answer': -4592.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-4592',
#   'Correct': 1},
#  {'Question': 'give me the product of 2882 and 4558',
#   'Answer': 13136156.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'calculate 6951 + 7313',
#   'Answer': 14264.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '14264',
#   'Correct': 1},
#  {'Question': 'give me the multiplication of 8261 and 6810',
#   'Answer': 56257410.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '56237310',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 1689 and 4533',
#   'Answer': 7656237.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '7662427',
#   'Correct': 0},
#  {'Question': 'give me the addition of 8327 and 9107',
#   'Answer': 17434.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '17434',
#   'Correct': 1},
#  {'Question': '7488 - 2461',
#   'Answer': 5027.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '5027',
#   'Correct': 1},
#  {'Question': 'give me the multiplication of 9057 and 9660',
#   'Answer': 87490620.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '87643220',
#   'Correct': 0},
#  {'Question': 'give me the addition of 6729 and 3101',
#   'Answer': 9830.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '9830',
#   'Correct': 1},
#  {'Question': 'find the product of 3561 and 1240',
#   'Answer': 4415640.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '4417960',
#   'Correct': 0},
#  {'Question': 'give me the subtraction of 7420 and 9108',
#   'Answer': -1688.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-1688',
#   'Correct': 1},
#  {'Question': 'what is the multiplication of 9901 * 3858',
#   'Answer': 38198058.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '38075158',
#   'Correct': 0},
#  {'Question': 'give me the addition of 6141 and 9996',
#   'Answer': 16137.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '16137',
#   'Correct': 1},
#  {'Question': 'find the quotient of 7250 and 6697',
#   'Answer': 1.0825742869941766,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '10.81',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 4962 and 4038',
#   'Answer': 20036556.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the addition of 1577 and 7857',
#   'Answer': 9434.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '9434',
#   'Correct': 1},
#  {'Question': 'what is 5264 divided by 6988',
#   'Answer': 0.7532913566113337,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.75',
#   'Correct': 0},
#  {'Question': 'give me the division of 9307 and 8246',
#   'Answer': 1.1286684453068154,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '11',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 2980 and 6555',
#   'Answer': 0.4546147978642257,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '45',
#   'Correct': 0},
#  {'Question': 'calculate 1053 - 4842',
#   'Answer': -3789.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-3789',
#   'Correct': 1},
#  {'Question': '5562 - 8294',
#   'Answer': -2732.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-2732',
#   'Correct': 1},
#  {'Question': 'what is the division of 5333 / 5970',
#   'Answer': 0.8932998324958124,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.89',
#   'Correct': 0},
#  {'Question': '3282 - 6104',
#   'Answer': -2822.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'can you tell me 7322 times 9410',
#   'Answer': 68900020.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '69165020',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 9299 and 8493',
#   'Answer': 78976407.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '78846247',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 8996 - 7774',
#   'Answer': 1222.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1222',
#   'Correct': 1},
#  {'Question': 'calculate 9468 / 9649',
#   'Answer': 0.9812415794382836,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.9817',
#   'Correct': 0},
#  {'Question': 'calculate 6982 / 4747',
#   'Answer': 1.470823678112492,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.47',
#   'Correct': 0},
#  {'Question': 'give me the addition of 4912 and 1116',
#   'Answer': 6028.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '6028',
#   'Correct': 1},
#  {'Question': 'give me the product of 5299 and 6696',
#   'Answer': 35482104.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '35389224',
#   'Correct': 0},
#  {'Question': '2841 / 8516',
#   'Answer': 0.3336073273837482,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.333',
#   'Correct': 0},
#  {'Question': 'give me the subtraction of 3768 and 2038',
#   'Answer': 1730.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1730',
#   'Correct': 1},
#  {'Question': 'can you tell me 7231 times 5427',
#   'Answer': 39242637.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': '6265 + 3096',
#   'Answer': 9361.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '9361',
#   'Correct': 1},
#  {'Question': 'give me the division of 1337 and 3062',
#   'Answer': 0.4366427171783148,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '4.37',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 7917 and 3456',
#   'Answer': 27361152.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '27405256',
#   'Correct': 0},
#  {'Question': 'tell me 8858 minus 5188',
#   'Answer': 3670.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '3670',
#   'Correct': 1},
#  {'Question': 'what is 1596 divided by 3835',
#   'Answer': 0.4161668839634941,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.416368690714913',
#   'Correct': 0},
#  {'Question': 'subtract 6048 from 5471',
#   'Answer': 577.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-585',
#   'Correct': 0},
#  {'Question': 'what is 1809 minus 9572',
#   'Answer': -7763.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-7763',
#   'Correct': 1},
#  {'Question': 'calculate 5424 * 8748',
#   'Answer': 47449152.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '4759152',
#   'Correct': 0},
#  {'Question': 'calculate 3947 + 9724',
#   'Answer': 13671.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '13671',
#   'Correct': 1},
#  {'Question': 'can you tell me 7238 times 8501',
#   'Answer': 61530238.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the addition of 7310 and 2859',
#   'Answer': 10169.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '10169',
#   'Correct': 1},
#  {'Question': 'find the sum of 2939 and 8222',
#   'Answer': 11161.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '11161',
#   'Correct': 1},
#  {'Question': 'what is 4759 divided by 2822',
#   'Answer': 1.686392629340893,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.683',
#   'Correct': 0},
#  {'Question': 'calculate 5137 - 7202',
#   'Answer': -2065.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the addition of 5796 and 1096',
#   'Answer': 6892.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '6892',
#   'Correct': 1},
#  {'Question': 'give me the division of 1811 and 5295',
#   'Answer': 0.3420207743153919,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '34',
#   'Correct': 0},
#  {'Question': 'what is the addition of 4928 + 8273',
#   'Answer': 13201.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '13201',
#   'Correct': 1},
#  {'Question': 'calculate 8740 + 5981',
#   'Answer': 14721.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '14721',
#   'Correct': 1},
#  {'Question': 'what is 4019 plus 9709',
#   'Answer': 13728.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '13728',
#   'Correct': 1},
#  {'Question': 'give me the multiplication of 2536 and 8755',
#   'Answer': 22202680.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '22184160',
#   'Correct': 0},
#  {'Question': 'give me the product of 8285 and 3316',
#   'Answer': 27473060.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 3742 plus 2885',
#   'Answer': 6627.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '6627',
#   'Correct': 1},
#  {'Question': 'what is 2536 - 7100',
#   'Answer': -4564.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-4564',
#   'Correct': 1},
#  {'Question': 'calculate 8575 + 3329',
#   'Answer': 11904.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '11904',
#   'Correct': 1},
#  {'Question': '9798 + 4000',
#   'Answer': 13798.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '13798',
#   'Correct': 1},
#  {'Question': 'give me the product of 1672 and 1707',
#   'Answer': 2854104.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '2851024',
#   'Correct': 0},
#  {'Question': 'give me the addition of 1147 and 7099',
#   'Answer': 8246.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '8246',
#   'Correct': 1},
#  {'Question': 'what is the multiplication of 2159 * 7450',
#   'Answer': 16084550.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '16124550',
#   'Correct': 0},
#  {'Question': '6430 - 8187',
#   'Answer': -1757.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-1757',
#   'Correct': 1},
#  {'Question': 'give me the subtraction of 1063 and 5499',
#   'Answer': -4436.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-4436',
#   'Correct': 1},
#  {'Question': 'give me the product of 6650 and 1350',
#   'Answer': 8977500.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8917500',
#   'Correct': 0},
#  {'Question': 'calculate 3959 / 7705',
#   'Answer': 0.5138221933809215,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.514',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 6257 - 4893',
#   'Answer': 1364.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1364',
#   'Correct': 1},
#  {'Question': 'give me the subtraction of 8311 and 4655',
#   'Answer': 3656.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '3656',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 4523 - 9889',
#   'Answer': -5366.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-5366',
#   'Correct': 1},
#  {'Question': '3768 / 9756',
#   'Answer': 0.3862238622386224,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '3.86',
#   'Correct': 0},
#  {'Question': '8757 / 5671',
#   'Answer': 1.544172103685417,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.54',
#   'Correct': 0},
#  {'Question': 'can you tell me 4488 times 4534',
#   'Answer': 20348592.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '20277792',
#   'Correct': 0},
#  {'Question': '9590 / 4767',
#   'Answer': 2.011747430249633,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '2',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 4271 and 7090',
#   'Answer': 30281390.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '30275490',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 9003 - 5726',
#   'Answer': 3277.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '3277',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 1661 - 3118',
#   'Answer': -1457.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-1457',
#   'Correct': 1},
#  {'Question': 'what is 7745 plus 9966',
#   'Answer': 17711.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '17711',
#   'Correct': 1},
#  {'Question': 'what is the addition of 7440 + 8629',
#   'Answer': 16069.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '16069',
#   'Correct': 1},
#  {'Question': 'what is 9184 plus 7041',
#   'Answer': 16225.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '16225',
#   'Correct': 1},
#  {'Question': 'calculate 9564 / 8922',
#   'Answer': 1.0719569603227976,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.07',
#   'Correct': 0},
#  {'Question': '2445 / 6966',
#   'Answer': 0.35099052540913,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.351',
#   'Correct': 0},
#  {'Question': '2937 + 7966',
#   'Answer': 10903.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '10903',
#   'Correct': 1},
#  {'Question': 'calculate 5606 + 3271',
#   'Answer': 8877.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '8877',
#   'Correct': 1},
#  {'Question': 'give me the subtraction of 9807 and 4259',
#   'Answer': 5548.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '5548',
#   'Correct': 1},
#  {'Question': '5488 + 7468',
#   'Answer': 12956.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '12956',
#   'Correct': 1},
#  {'Question': 'can you tell me 6594 times 4789',
#   'Answer': 31578666.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '31374376',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 6525 and 3372',
#   'Answer': 22002300.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '22023100',
#   'Correct': 0},
#  {'Question': 'calculate 3750 + 8835',
#   'Answer': 12585.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '12585',
#   'Correct': 1},
#  {'Question': 'what is the addition of 3732 + 9161',
#   'Answer': 12893.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '12893',
#   'Correct': 1},
#  {'Question': 'give me the addition of 3496 and 6375',
#   'Answer': 9871.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '9871',
#   'Correct': 1},
#  {'Question': 'what is the addition of 6398 + 1174',
#   'Answer': 7572.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '7572',
#   'Correct': 1},
#  {'Question': 'calculate 2522 - 7803',
#   'Answer': -5281.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-5281',
#   'Correct': 1},
#  {'Question': 'what is the division of 2171 / 1405',
#   'Answer': 1.5451957295373666,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.545',
#   'Correct': 0},
#  {'Question': 'give me the division of 1265 and 1953',
#   'Answer': 0.647721454173067,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '6.5',
#   'Correct': 0},
#  {'Question': 'find the quotient of 3480 and 5358',
#   'Answer': 0.6494960806270996,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.65',
#   'Correct': 0},
#  {'Question': 'what is 2387 times 7163',
#   'Answer': 17098081.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '17107181',
#   'Correct': 0},
#  {'Question': 'calculate 2652 * 9628',
#   'Answer': 25533456.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '25529376',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 5205 and 7904',
#   'Answer': 41140320.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 7763 plus 6790',
#   'Answer': 14553.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '14553',
#   'Correct': 1},
#  {'Question': 'calculate 4612 * 1513',
#   'Answer': 6977956.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '6979176',
#   'Correct': 0},
#  {'Question': 'what is 7363 plus 8338',
#   'Answer': 15701.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '15701',
#   'Correct': 1},
#  {'Question': 'what is 8477 minus 4341',
#   'Answer': 4136.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '4136',
#   'Correct': 1},
#  {'Question': '2645 / 2731',
#   'Answer': 0.968509703405346,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.9681',
#   'Correct': 0},
#  {'Question': 'tell me 8649 minus 7577',
#   'Answer': 1072.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1072',
#   'Correct': 1},
#  {'Question': 'find the product of 9816 and 9536',
#   'Answer': 93605376.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '93617216',
#   'Correct': 0},
#  {'Question': 'give me the division of 3699 and 6130',
#   'Answer': 0.6034257748776509,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 2806 and 7393',
#   'Answer': 0.3795482212904098,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': 'what is the division of 2025 / 4044',
#   'Answer': 0.5007418397626113,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.5',
#   'Correct': 0},
#  {'Question': 'give me the division of 5774 and 8310',
#   'Answer': 0.6948255114320097,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the quotient of 8671 and 1347',
#   'Answer': 6.437268002969562,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '6',
#   'Correct': 0},
#  {'Question': '6220 times 6957',
#   'Answer': 43272540.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '43294340',
#   'Correct': 0},
#  {'Question': 'what is 3544 - 7878',
#   'Answer': -4334.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-4334',
#   'Correct': 1},
#  {'Question': 'calculate 2309 * 7457',
#   'Answer': 17218213.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '17248333',
#   'Correct': 0},
#  {'Question': '8846 + 2697',
#   'Answer': 11543.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '11543',
#   'Correct': 1},
#  {'Question': 'can you tell me 8652 times 4137',
#   'Answer': 35793324.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '35641184',
#   'Correct': 0},
#  {'Question': 'calculate 1999 - 8550',
#   'Answer': -6551.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-6551',
#   'Correct': 1},
#  {'Question': '2029 / 8272',
#   'Answer': 0.2452852998065764,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 2031 divided by 7728',
#   'Answer': 0.2628105590062112,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.26',
#   'Correct': 0},
#  {'Question': 'calculate 2611 + 6379',
#   'Answer': 8990.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8990',
#   'Correct': 1},
#  {'Question': 'what is 4602 divided by 5867',
#   'Answer': 0.7843872507243906,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.7845',
#   'Correct': 0},
#  {'Question': '7036 / 9274',
#   'Answer': 0.7586801811516066,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.76',
#   'Correct': 0},
#  {'Question': 'give me the division of 5617 and 5479',
#   'Answer': 1.0251870779339296,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '10.25',
#   'Correct': 0},
#  {'Question': 'what is 5332 plus 3061',
#   'Answer': 8393.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '8393',
#   'Correct': 1},
#  {'Question': '4004 - 1959',
#   'Answer': 2045.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '2045',
#   'Correct': 1},
#  {'Question': 'tell me 3113 minus 4442',
#   'Answer': -1329.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-1329',
#   'Correct': 1},
#  {'Question': 'what is 5782 divided by 8544',
#   'Answer': 0.6767322097378277,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.68',
#   'Correct': 0},
#  {'Question': 'what is the division of 3013 / 9340',
#   'Answer': 0.3225910064239828,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.3229',
#   'Correct': 0},
#  {'Question': 'what is 5468 times 3253',
#   'Answer': 17787404.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'calculate 2235 / 7727',
#   'Answer': 0.2892455027824511,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.2895',
#   'Correct': 0},
#  {'Question': '9982 + 1035',
#   'Answer': 11017.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '11017',
#   'Correct': 1},
#  {'Question': 'find the sum of 5175 and 7401',
#   'Answer': 12576.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '12576',
#   'Correct': 1},
#  {'Question': 'what is the division of 8137 / 9458',
#   'Answer': 0.8603298794671178,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.86',
#   'Correct': 0},
#  {'Question': 'calculate 1821 - 9121',
#   'Answer': -7300.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-7300',
#   'Correct': 1},
#  {'Question': 'find the product of 4625 and 8484',
#   'Answer': 39238500.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'calculate 4339 * 6485',
#   'Answer': 28138415.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 9451 minus 7732',
#   'Answer': 1719.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1719',
#   'Correct': 1},
#  {'Question': 'calculate 5091 + 8593',
#   'Answer': 13684.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '13684',
#   'Correct': 1},
#  {'Question': 'tell me 5889 minus 6275',
#   'Answer': -386.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-386',
#   'Correct': 1},
#  {'Question': 'give me the quotient of 3308 and 2713',
#   'Answer': 1.2193144120899373,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'calculate 6830 / 9459',
#   'Answer': 0.7220636430912358,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.721',
#   'Correct': 0},
#  {'Question': '2505 times 1790',
#   'Answer': 4483950.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '446975',
#   'Correct': 0},
#  {'Question': 'calculate 1412 / 1784',
#   'Answer': 0.7914798206278026,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.79',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 6386 - 6933',
#   'Answer': -547.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-547',
#   'Correct': 1},
#  {'Question': '9566 times 8246',
#   'Answer': 78881236.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is the multiplication of 4336 * 3001',
#   'Answer': 13012336.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '13013636',
#   'Correct': 0},
#  {'Question': 'find the sum of 2851 and 4831',
#   'Answer': 7682.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '7682',
#   'Correct': 1},
#  {'Question': 'what is the division of 8338 / 7486',
#   'Answer': 1.113812449906492,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.116',
#   'Correct': 0},
#  {'Question': 'calculate 3342 / 8597',
#   'Answer': 0.388740258229615,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.39',
#   'Correct': 0},
#  {'Question': 'find the product of 6488 and 7015',
#   'Answer': 45513320.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '45600880',
#   'Correct': 0},
#  {'Question': '6275 / 7456',
#   'Answer': 0.8416040772532188,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.8422',
#   'Correct': 0},
#  {'Question': 'what is the multiplication of 1903 * 2841',
#   'Answer': 5406423.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '5393963',
#   'Correct': 0},
#  {'Question': 'give me the product of 2977 and 2944',
#   'Answer': 8764288.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '8754888',
#   'Correct': 0},
#  {'Question': 'find the product of 6339 and 2463',
#   'Answer': 15612957.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '15583897',
#   'Correct': 0},
#  {'Question': '7529 / 3974',
#   'Answer': 1.894564670357323,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1.89',
#   'Correct': 0},
#  {'Question': 'what is 3765 times 7050',
#   'Answer': 26543250.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '26548250',
#   'Correct': 0},
#  {'Question': 'give me the subtraction of 7980 and 8210',
#   'Answer': -230.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-230',
#   'Correct': 1},
#  {'Question': '2182 - 9123',
#   'Answer': -6941.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-6941',
#   'Correct': 1},
#  {'Question': 'what is 1552 times 5641',
#   'Answer': 8754832.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '8785552',
#   'Correct': 0},
#  {'Question': 'find the sum of 9160 and 3769',
#   'Answer': 12929.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '12929',
#   'Correct': 1},
#  {'Question': 'what is 7828 - 2938',
#   'Answer': 4890.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '4890',
#   'Correct': 1},
#  {'Question': '3864 + 7406',
#   'Answer': 11270.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '11270',
#   'Correct': 1},
#  {'Question': '5353 / 7683',
#   'Answer': 0.6967330469868541,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.6983',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 2537 - 8956',
#   'Answer': -6419.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-6419',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 9521 - 8969',
#   'Answer': 552.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '552',
#   'Correct': 1},
#  {'Question': 'what is 7685 minus 2890',
#   'Answer': 4795.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '4795',
#   'Correct': 1},
#  {'Question': 'what is 5919 plus 2488',
#   'Answer': 8407.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': None,
#   'Correct': 0},
#  {'Question': 'give me the addition of 6324 and 8419',
#   'Answer': 14743.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '14743',
#   'Correct': 1},
#  {'Question': 'can you tell me 5800 times 9001',
#   'Answer': 52205800.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 2281 divided by 3670',
#   'Answer': 0.6215258855585831,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.6215',
#   'Correct': 0},
#  {'Question': 'give me the division of 1261 and 6163',
#   'Answer': 0.2046081453837417,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '20',
#   'Correct': 0},
#  {'Question': 'calculate 8162 * 1958',
#   'Answer': 15981196.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '15991456',
#   'Correct': 0},
#  {'Question': 'what is 8939 times 5134',
#   'Answer': 45892826.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '45813916',
#   'Correct': 0},
#  {'Question': '4155 + 8796',
#   'Answer': 12951.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '12951',
#   'Correct': 1},
#  {'Question': 'find the quotient of 7674 and 6279',
#   'Answer': 1.2221691352126134,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.22304006603',
#   'Correct': 0},
#  {'Question': 'what is the addition of 1558 + 6574',
#   'Answer': 8132.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8132',
#   'Correct': 1},
#  {'Question': '4944 / 4512',
#   'Answer': 1.0957446808510638,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.1',
#   'Correct': 0},
#  {'Question': 'calculate 5276 + 5244',
#   'Answer': 10520.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '10520',
#   'Correct': 1},
#  {'Question': 'what is the division of 2183 / 7740',
#   'Answer': 0.2820413436692506,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.282',
#   'Correct': 0},
#  {'Question': 'calculate 2619 - 5282',
#   'Answer': -2663.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-2663',
#   'Correct': 1},
#  {'Question': 'calculate 8256 * 4269',
#   'Answer': 35244864.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '35200224',
#   'Correct': 0},
#  {'Question': 'subtract 3729 from 3709',
#   'Answer': 20.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-20',
#   'Correct': 0},
#  {'Question': 'what is the addition of 5418 + 6983',
#   'Answer': 12401.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '12401',
#   'Correct': 1},
#  {'Question': 'calculate 9275 / 2480',
#   'Answer': 3.7399193548387095,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '3.74',
#   'Correct': 0},
#  {'Question': 'what is 3966 divided by 7095',
#   'Answer': 0.5589852008456659,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.56',
#   'Correct': 0},
#  {'Question': 'what is 1185 times 9486',
#   'Answer': 11240910.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '11241460',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 3017 - 8755',
#   'Answer': -5738.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-5738',
#   'Correct': 1},
#  {'Question': 'calculate 6112 - 9998',
#   'Answer': -3886.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-3886',
#   'Correct': 1},
#  {'Question': 'give me the addition of 8453 and 1785',
#   'Answer': 10238.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '10238',
#   'Correct': 1},
#  {'Question': '4930 - 3076',
#   'Answer': 1854.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1854',
#   'Correct': 1},
#  {'Question': '8186 - 3432',
#   'Answer': 4754.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '4754',
#   'Correct': 1},
#  {'Question': 'give me the quotient of 2211 and 6355',
#   'Answer': 0.3479150275373721,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '3.48',
#   'Correct': 0},
#  {'Question': 'what is the division of 6853 / 6027',
#   'Answer': 1.1370499419279907,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.136',
#   'Correct': 0},
#  {'Question': 'what is 9771 plus 4308',
#   'Answer': 14079.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '14079',
#   'Correct': 1},
#  {'Question': 'calculate 8463 / 9899',
#   'Answer': 0.8549348419032226,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.856',
#   'Correct': 0},
#  {'Question': 'give me the addition of 1221 and 1079',
#   'Answer': 2300.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '2300',
#   'Correct': 1},
#  {'Question': 'what is the addition of 1167 + 7239',
#   'Answer': 8406.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '8406',
#   'Correct': 1},
#  {'Question': 'what is the division of 1643 / 4266',
#   'Answer': 0.3851383028598218,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': '9910 - 3890',
#   'Answer': 6020.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '6020',
#   'Correct': 1},
#  {'Question': '1333 / 8089',
#   'Answer': 0.1647916924218073,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1.65',
#   'Correct': 0},
#  {'Question': 'calculate 2088 - 2387',
#   'Answer': -299.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-299',
#   'Correct': 1},
#  {'Question': 'find the quotient of 6531 and 7536',
#   'Answer': 0.866640127388535,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': 'find the sum of 2427 and 3021',
#   'Answer': 5448.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '5448',
#   'Correct': 1},
#  {'Question': 'what is 1348 plus 3624',
#   'Answer': 4972.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '4972',
#   'Correct': 1},
#  {'Question': 'give me the product of 9635 and 1043',
#   'Answer': 10049305.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '9995055',
#   'Correct': 0},
#  {'Question': 'find the product of 2810 and 2943',
#   'Answer': 8269830.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'find the quotient of 8578 and 7196',
#   'Answer': 1.1920511395219566,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '12',
#   'Correct': 0},
#  {'Question': 'calculate 6445 + 3328',
#   'Answer': 9773.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '9773',
#   'Correct': 1},
#  {'Question': 'give me the addition of 2939 and 3252',
#   'Answer': 6191.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '6191',
#   'Correct': 1},
#  {'Question': 'what is 9273 divided by 5785',
#   'Answer': 1.6029386343993086,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.6',
#   'Correct': 0},
#  {'Question': 'what is the addition of 2314 + 2834',
#   'Answer': 5148.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '5148',
#   'Correct': 1},
#  {'Question': '8300 + 6904',
#   'Answer': 15204.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '15204',
#   'Correct': 1},
#  {'Question': 'find the quotient of 8219 and 1947',
#   'Answer': 4.221366204417052,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '4',
#   'Correct': 0},
#  {'Question': 'calculate 7258 * 4175',
#   'Answer': 30302150.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is the division of 8975 / 7723',
#   'Answer': 1.1621131684578532,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'what is 7217 minus 8508',
#   'Answer': -1291.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-1291',
#   'Correct': 1},
#  {'Question': 'calculate 9303 - 7671',
#   'Answer': 1632.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1632',
#   'Correct': 1},
#  {'Question': 'subtract 3970 from 3545',
#   'Answer': 425.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-425',
#   'Correct': 0},
#  {'Question': '4800 times 2352',
#   'Answer': 11289600.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '11289600',
#   'Correct': 1},
#  {'Question': 'find the sum of 2294 and 7955',
#   'Answer': 10249.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '10249',
#   'Correct': 1},
#  {'Question': 'calculate 3011 / 9509',
#   'Answer': 0.3166473866862972,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.3166',
#   'Correct': 0},
#  {'Question': 'give me the subtraction of 2110 and 5311',
#   'Answer': -3201.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-3201',
#   'Correct': 1},
#  {'Question': 'calculate 5642 * 8548',
#   'Answer': 48227816.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'calculate 9965 / 9487',
#   'Answer': 1.050384737008538,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1.05',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 9868 and 5970',
#   'Answer': 58911960.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '58740460',
#   'Correct': 0},
#  {'Question': 'what is 1855 times 9214',
#   'Answer': 17091970.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the subtraction of 8799 and 2810',
#   'Answer': 5989.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '5989',
#   'Correct': 1},
#  {'Question': 'what is the division of 2659 / 1832',
#   'Answer': 1.4514192139737991,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'what is 7949 divided by 6611',
#   'Answer': 1.2023899561337166,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'tell me 9509 minus 6301',
#   'Answer': 3208.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '3208',
#   'Correct': 1},
#  {'Question': 'calculate 6463 + 1415',
#   'Answer': 7878.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '7878',
#   'Correct': 1},
#  {'Question': 'what is 8891 - 5342',
#   'Answer': 3549.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '3549',
#   'Correct': 1},
#  {'Question': 'what is the division of 6362 / 4374',
#   'Answer': 1.454503886602652,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1.45',
#   'Correct': 0},
#  {'Question': 'tell me 2039 minus 2405',
#   'Answer': -366.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-366',
#   'Correct': 1},
#  {'Question': 'calculate 4329 * 7374',
#   'Answer': 31922046.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': '1740 / 2421',
#   'Answer': 0.7187112763320942,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.719',
#   'Correct': 0},
#  {'Question': 'can you tell me 8380 times 7070',
#   'Answer': 59246600.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '59090460',
#   'Correct': 0},
#  {'Question': 'calculate 2170 / 5920',
#   'Answer': 0.366554054054054,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.3684',
#   'Correct': 0},
#  {'Question': 'give me the product of 7937 and 6382',
#   'Answer': 50653934.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'find the sum of 9358 and 8144',
#   'Answer': 17502.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '17502',
#   'Correct': 1},
#  {'Question': 'what is 3088 times 3165',
#   'Answer': 9773520.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '9764720',
#   'Correct': 0},
#  {'Question': 'what is 4603 - 2813',
#   'Answer': 1790.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1790',
#   'Correct': 1},
#  {'Question': 'find the product of 4056 and 2065',
#   'Answer': 8375640.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '8349840',
#   'Correct': 0},
#  {'Question': 'what is the multiplication of 9236 * 9397',
#   'Answer': 86790692.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '86841282',
#   'Correct': 0},
#  {'Question': 'calculate 6115 * 8756',
#   'Answer': 53542940.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '53492440',
#   'Correct': 0},
#  {'Question': 'what is 5227 times 5029',
#   'Answer': 26286583.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '26330963',
#   'Correct': 0},
#  {'Question': '1109 / 6864',
#   'Answer': 0.161567599067599,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.1615',
#   'Correct': 0},
#  {'Question': 'calculate 9065 + 9930',
#   'Answer': 18995.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '19995',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 6198 and 7339',
#   'Answer': 0.8445292274151792,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': 'what is 8262 minus 9160',
#   'Answer': -898.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-898',
#   'Correct': 1},
#  {'Question': 'what is the addition of 1057 + 8963',
#   'Answer': 10020.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '10020',
#   'Correct': 1},
#  {'Question': '4060 + 5631',
#   'Answer': 9691.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '9691',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 8830 - 8953',
#   'Answer': -123.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-123',
#   'Correct': 1},
#  {'Question': 'give me the addition of 3759 and 7440',
#   'Answer': 11199.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '11199',
#   'Correct': 1},
#  {'Question': 'what is 1699 - 5178',
#   'Answer': -3479.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-3479',
#   'Correct': 1},
#  {'Question': 'can you tell me 6468 times 2382',
#   'Answer': 15406776.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '15439416',
#   'Correct': 0},
#  {'Question': 'can you tell me 7420 times 9895',
#   'Answer': 73420900.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '7.31381e+07',
#   'Correct': 0},
#  {'Question': 'what is 8509 minus 7349',
#   'Answer': 1160.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1160',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 1903 - 9891',
#   'Answer': -7988.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-7988',
#   'Correct': 1},
#  {'Question': 'what is 2625 - 5008',
#   'Answer': -2383.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-2383',
#   'Correct': 1},
#  {'Question': 'give me the subtraction of 3351 and 2148',
#   'Answer': 1203.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1203',
#   'Correct': 1},
#  {'Question': 'what is the multiplication of 9969 * 3312',
#   'Answer': 33017328.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '32892552',
#   'Correct': 0},
#  {'Question': 'what is 4221 minus 9662',
#   'Answer': -5441.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-5441',
#   'Correct': 1},
#  {'Question': 'what is the multiplication of 4674 * 9824',
#   'Answer': 45917376.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '45784426',
#   'Correct': 0},
#  {'Question': 'calculate 4703 * 4959',
#   'Answer': 23322177.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '23253447',
#   'Correct': 0},
#  {'Question': 'calculate 2308 / 3269',
#   'Answer': 0.7060263077393698,
# ...
#   'Answer': 0.2052034179313863,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.205',
#   'Correct': 0},
#  {'Question': '4863 + 5594',
#   'Answer': 10457.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '10457',
#   'Correct': 1},
#  {'Question': '3304 + 6891',
#   'Answer': 10195.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '10195',
#   'Correct': 1},
#  {'Question': 'what is 9209 minus 6671',
#   'Answer': 2538.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '2538',
#   'Correct': 1},
#  {'Question': '2679 times 1506',
#   'Answer': 4034574.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is the multiplication of 4996 * 5019',
#   'Answer': 25074924.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '24580964',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 9078 and 2736',
#   'Answer': 24837408.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is 8025 divided by 9928',
#   'Answer': 0.8083199033037872,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.808',
#   'Correct': 0},
#  {'Question': 'what is 1171 - 8929',
#   'Answer': -7758.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-7758',
#   'Correct': 1},
#  {'Question': 'calculate 4046 / 4982',
#   'Answer': 0.8121236451224408,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.81',
#   'Correct': 0},
#  {'Question': 'give me the subtraction of 6473 and 1962',
#   'Answer': 4511.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '4511',
#   'Correct': 1},
#  {'Question': '9252 / 9115',
#   'Answer': 1.0150301700493691,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1.015',
#   'Correct': 0},
#  {'Question': 'what is 4145 plus 4955',
#   'Answer': 9100.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '9000',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 6735 and 2987',
#   'Answer': 2.2547706729159693,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '2',
#   'Correct': 0},
#  {'Question': 'what is 7173 - 7440',
#   'Answer': -267.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': None,
#   'Correct': 0},
#  {'Question': 'give me the quotient of 3313 and 9705',
#   'Answer': 0.3413704276146316,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': 'find the sum of 2401 and 2965',
#   'Answer': 5366.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '5366',
#   'Correct': 1},
#  {'Question': 'calculate 5148 + 5726',
#   'Answer': 10874.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '10874',
#   'Correct': 1},
#  {'Question': 'what is 2578 plus 5322',
#   'Answer': 7900.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '7900',
#   'Correct': 1},
#  {'Question': 'what is 8350 plus 8723',
#   'Answer': 17073.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '17073',
#   'Correct': 1},
#  {'Question': 'calculate 1717 * 7237',
#   'Answer': 12425929.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '12359149',
#   'Correct': 0},
#  {'Question': '4847 + 7554',
#   'Answer': 12401.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '12401',
#   'Correct': 1},
#  {'Question': 'give me the multiplication of 8469 and 7293',
#   'Answer': 61764417.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Four digits',
#   'Predicted': '61754877',
#   'Correct': 0},
#  {'Question': 'what is the addition of 4232 + 4517',
#   'Answer': 8749.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8749',
#   'Correct': 1},
#  {'Question': 'what is the subtraction of 3795 - 2507',
#   'Answer': 1288.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1288',
#   'Correct': 1},
#  {'Question': 'calculate 5950 - 4692',
#   'Answer': 1258.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1258',
#   'Correct': 1},
#  {'Question': 'what is the division of 1873 / 8808',
#   'Answer': 0.2126475930971843,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.2127',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 9788 and 3835',
#   'Answer': 2.552281616688396,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '2.55',
#   'Correct': 0},
#  {'Question': 'what is 6757 divided by 5444',
#   'Answer': 1.241182953710507,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'find the quotient of 9578 and 7211',
#   'Answer': 1.328248509222022,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 7473 and 2996',
#   'Answer': 2.4943257676902535,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '2',
#   'Correct': 0},
#  {'Question': 'what is the addition of 1664 + 7521',
#   'Answer': 9185.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '9185',
#   'Correct': 1},
#  {'Question': 'tell me 3349 minus 6859',
#   'Answer': -3510.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-3510',
#   'Correct': 1},
#  {'Question': 'what is 5408 plus 9571',
#   'Answer': 14979.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '14979',
#   'Correct': 1},
#  {'Question': 'give me the addition of 3043 and 5844',
#   'Answer': 8887.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8887',
#   'Correct': 1},
#  {'Question': 'find the product of 5353 and 9906',
#   'Answer': 53026818.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '52999418',
#   'Correct': 0},
#  {'Question': 'give me the division of 6143 and 9190',
#   'Answer': 0.6684439608269859,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '6.669',
#   'Correct': 0},
#  {'Question': 'subtract 3151 from 5720',
#   'Answer': -2569.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '2569',
#   'Correct': 0},
#  {'Question': 'what is 2943 plus 2796',
#   'Answer': 5739.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '5739',
#   'Correct': 1},
#  {'Question': '6550 - 5447',
#   'Answer': 1103.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1103',
#   'Correct': 1},
#  {'Question': '2307 times 3200',
#   'Answer': 7382400.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the division of 8103 and 3037',
#   'Answer': 2.668093513335529,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '2',
#   'Correct': 0},
#  {'Question': 'what is the multiplication of 4074 * 5592',
#   'Answer': 22781808.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '227862048',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 7276 - 9957',
#   'Answer': -2681.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-2681',
#   'Correct': 1},
#  {'Question': 'subtract 5347 from 5956',
#   'Answer': -609.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '609',
#   'Correct': 0},
#  {'Question': 'subtract 2998 from 3332',
#   'Answer': -334.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '334',
#   'Correct': 0},
#  {'Question': 'what is 9377 plus 4417',
#   'Answer': 13794.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '13794',
#   'Correct': 1},
#  {'Question': 'give me the product of 8013 and 6149',
#   'Answer': 49271937.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'what is the division of 8578 / 8074',
#   'Answer': 1.0624225910329452,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '1',
#   'Correct': 0},
#  {'Question': '5792 + 8013',
#   'Answer': 13805.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '13805',
#   'Correct': 1},
#  {'Question': 'find the sum of 7907 and 9169',
#   'Answer': 17076.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '17076',
#   'Correct': 1},
#  {'Question': 'find the quotient of 6149 and 1077',
#   'Answer': 5.709377901578459,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '5.714',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 8972 - 9818',
#   'Answer': -846.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-846',
#   'Correct': 1},
#  {'Question': 'find the product of 4258 and 7915',
#   'Answer': 33702070.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '33639110',
#   'Correct': 0},
#  {'Question': 'what is 1492 plus 3119',
#   'Answer': 4611.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '4611',
#   'Correct': 1},
#  {'Question': 'subtract 8865 from 9736',
#   'Answer': -871.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '8671',
#   'Correct': 0},
#  {'Question': '5043 + 1137',
#   'Answer': 6180.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '6180',
#   'Correct': 1},
#  {'Question': 'calculate 3435 + 5478',
#   'Answer': 8913.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '8913',
#   'Correct': 1},
#  {'Question': 'calculate 2645 / 1589',
#   'Answer': 1.6645689112649464,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1.665',
#   'Correct': 0},
#  {'Question': 'what is the addition of 3770 + 8284',
#   'Answer': 12054.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '12054',
#   'Correct': 1},
#  {'Question': 'calculate 2926 / 3857',
#   'Answer': 0.7586206896551724,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0.7591',
#   'Correct': 0},
#  {'Question': 'find the quotient of 7206 and 2663',
#   'Answer': 2.705970709725873,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '2.71',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 4335 and 4525',
#   'Answer': 0.958011049723757,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '0.956',
#   'Correct': 0},
#  {'Question': '3138 / 1498',
#   'Answer': 2.0947930574098796,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '2',
#   'Correct': 0},
#  {'Question': 'what is 6082 minus 6066',
#   'Answer': 16.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '16',
#   'Correct': 1},
#  {'Question': '6474 - 5670',
#   'Answer': 804.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '804',
#   'Correct': 1},
#  {'Question': 'give me the subtraction of 5156 and 8039',
#   'Answer': -2883.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '-2883',
#   'Correct': 1},
#  {'Question': '4926 - 4884',
#   'Answer': 42.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '42',
#   'Correct': 1},
#  {'Question': 'find the product of 9975 and 4076',
#   'Answer': 40658100.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 7747 and 2761',
#   'Answer': 21389467.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '21371097',
#   'Correct': 0},
#  {'Question': 'calculate 7982 / 6208',
#   'Answer': 1.2857603092783505,
#   'Operator': 'division',
#   'Num_Digits': 'Three digits',
#   'Predicted': '1.285',
#   'Correct': 0},
#  {'Question': 'calculate 7969 - 9594',
#   'Answer': -1625.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Three digits',
#   'Predicted': '-1625',
#   'Correct': 1},
#  {'Question': '1655 + 4796',
#   'Answer': 6451.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '6451',
#   'Correct': 1},
#  {'Question': 'find the quotient of 7747 and 9933',
#   'Answer': 0.7799255008557334,
#   'Operator': 'division',
#   'Num_Digits': 'Five digits',
#   'Predicted': '0',
#   'Correct': 0},
#  {'Question': '4113 times 1126',
#   'Answer': 4631238.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'subtract 3555 from 1283',
#   'Answer': 2272.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '928',
#   'Correct': 0},
#  {'Question': 'give me the quotient of 4582 and 7618',
#   'Answer': 0.601470202152796,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.6',
#   'Correct': 0},
#  {'Question': 'calculate 3494 + 8398',
#   'Answer': 11892.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Four digits',
#   'Predicted': '11892',
#   'Correct': 1},
#  {'Question': 'what is the division of 9052 / 7585',
#   'Answer': 1.19340804218853,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.120',
#   'Correct': 0},
#  {'Question': 'give me the addition of 5608 and 1652',
#   'Answer': 7260.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Five digits',
#   'Predicted': '7260',
#   'Correct': 1},
#  {'Question': 'calculate 5382 / 1766',
#   'Answer': 3.0475651189127975,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '3',
#   'Correct': 0},
#  {'Question': 'find the sum of 4559 and 8503',
#   'Answer': 13062.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '13062',
#   'Correct': 1},
#  {'Question': '3561 times 2361',
#   'Answer': 8407521.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '8367121',
#   'Correct': 0},
#  {'Question': 'give me the multiplication of 1217 and 9436',
#   'Answer': 11483612.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Three digits',
#   'Predicted': '11504622',
#   'Correct': 0},
#  {'Question': 'calculate 8755 - 2190',
#   'Answer': 6565.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '6565',
#   'Correct': 1},
#  {'Question': 'calculate 7008 - 1671',
#   'Answer': 5337.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Four digits',
#   'Predicted': '5337',
#   'Correct': 1},
#  {'Question': 'give me the subtraction of 9813 and 7095',
#   'Answer': 2718.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '2718',
#   'Correct': 1},
#  {'Question': 'calculate 1633 * 6427',
#   'Answer': 10495291.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': '10450701',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 6633 - 7574',
#   'Answer': -941.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-941',
#   'Correct': 1},
#  {'Question': 'calculate 7855 / 6712',
#   'Answer': 1.170292014302741,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '1.17',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 8929 - 8567',
#   'Answer': 362.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '362',
#   'Correct': 1},
#  {'Question': 'calculate 8656 * 3803',
#   'Answer': 32918768.0,
#   'Operator': 'multiplication',
#   'Num_Digits': 'Five digits',
#   'Predicted': inf,
#   'Correct': 0},
#  {'Question': 'calculate 9950 + 6705',
#   'Answer': 16655.0,
#   'Operator': 'addition',
#   'Num_Digits': 'Three digits',
#   'Predicted': '16655',
#   'Correct': 1},
#  {'Question': 'what is 6983 divided by 7526',
#   'Answer': 0.9278501195854372,
#   'Operator': 'division',
#   'Num_Digits': 'Four digits',
#   'Predicted': '0.9271',
#   'Correct': 0},
#  {'Question': 'what is the subtraction of 3931 - 4280',
#   'Answer': -349.0,
#   'Operator': 'subtraction',
#   'Num_Digits': 'Five digits',
#   'Predicted': '-349',
#   'Correct': 1},
#  ...]

# %%
results3 = pd.DataFrame(data_list)
results3.to_csv("results3.csv", index=False)

# %%
zeroshot_results = zero_shot_prompt_chatgpt(dataset[0:500]) # 47 # gpt-3.5-turbo-0125
# evaluate(zeroshot_results, answers)  # This should give you scores 38-50%
# Out:
# 184it [20:22,  6.95s/it]
# An error occurred: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# 442it [49:42,  5.96s/it]
# An error occurred: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# 500it [56:10,  6.74s/it]

# %%
zeroshot_results = zero_shot_prompt_chatgpt(dataset[1501:3500]) # 47 # gpt-3.5-turbo-0125
# Out:
# 1193it [2:16:03,  6.12s/it]
# An error occurred: The `response.text` quick accessor only works when the response contains a valid `Part`, but none was returned. Check the `candidate.safety_ratings` to see if the response was blocked.
# 1549it [2:57:06,  6.86s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 zeroshot_results = zero_shot_prompt_chatgpt(dataset[1501:3500]) # 47 # gpt-3.5-turbo-0125
#
# Cell In[51], line 34, in zero_shot_prompt_chatgpt(test_dataset)
#      32 example_prompt =  context + " " + question
#      33 try:
# ---> 34     chatgpt_output = chatgpt_completion(example_prompt)
#      35     result = parse_zeroshot_chatgpt_output(chatgpt_output)
#      36 except Exception as e:
#
# Cell In[43], line 7, in chatgpt_completion(prompt_text)
#       5 prompt = "GIVE ME ONLY THE RESULT " + prompt_text
#       6 model = genai.GenerativeModel('gemini-pro')
# ----> 7 response = model.generate_content(prompt)
#       8 return response.text
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/generativeai/generative_models.py:262, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     260         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     261     else:
# --> 262         response = self._client.generate_content(
#     263             request,
#     264             **request_options,
#     265         )
#     266         return generation_types.GenerateContentResponse.from_response(response)
#     267 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:791, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     788 self._validate_universe_domain()
#     790 # Send the request.
# --> 791 response = rpc(
#     792     request,
#     793     retry=retry,
#     794     timeout=timeout,
#     795     metadata=metadata,
#     796 )
#     798 # Done; return the response.
#     799 return response
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/grpc/_channel.py:1173, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def __call__(
#    1162     self,
#    1163     request: Any,
#    (...)
#    1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Any:
#    1170     (
#    1171         state,
#    1172         call,
# -> 1173     ) = self._blocking(
#    1174         request, timeout, metadata, credentials, wait_for_ready, compression
#    1175     )
#    1176     return _end_unary_response_blocking(state, call, False, None)
#
# File ~/miniforge3/envs/gemini/lib/python3.12/site-packages/grpc/_channel.py:1157, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1141 state.target = _common.decode(self._target)
#    1142 call = self._channel.segregated_call(
#    1143     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1144     self._method,
#    (...)
#    1155     self._context,
#    1156 )
# -> 1157 event = call.next_event()
#    1158 _handle_event(event, state, self._response_deserializer)
#    1159 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:367, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:188, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:182, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
zeroshot_results
# Out:
#                                    Question        Answer        Operator  \
# 0     give me the addition of 6772 and 2099  8.871000e+03        addition
# 1                       what is 3368 - 8917 -5.549000e+03     subtraction
# 2     give me the quotient of 6509 and 4865  1.337924e+00        division
# 3                     calculate 6322 - 7087 -7.650000e+02     subtraction
# 4                           2532 times 2501  6.332532e+06  multiplication
# ...                                     ...           ...             ...
# 1494                  calculate 2065 * 8100  1.672650e+07  multiplication
# 1495   give me the product of 8015 and 6392  5.123188e+07  multiplication
# 1496                  calculate 9351 / 1231  7.596263e+00        division
# 1497                            9925 + 3141  1.306600e+04        addition
# 1498                    what is 1829 - 4244 -2.415000e+03     subtraction
#
#         Num_Digits Predicted  Correct
# 0      Five digits      8871        1
# 1      Four digits     -5549        1
# 2      Five digits         1        0
# 3     Three digits      -765        1
# 4     Three digits       inf        0
# ...            ...       ...      ...
# 1494   Four digits       inf        0
# 1495   Five digits  51168960        0
# 1496   Four digits       7.6        0
# 1497  Three digits     13066        1
# 1498  Three digits     -2415        1
#
# [1499 rows x 6 columns]

# %%
zeroshot_results.to_csv('zeroshot_results_gemini3.csv', index=False)

# %%
evaluate(zeroshot_results['Predicted'], 
         zeroshot_results['Answer'])
# Out:
# 8871.0 8871.0
# -5549.0 -5549.0
# 1.34 1.33792394655704
# -764.0 -765.0
# 6335832.0 6332532.0
# 2.25 2.2545405982905984
# 13066.0 13066.0
# 14130.0 14130.0
# -5073.0 -5073.0
# 15495.0 15495.0
# The scores on the test set:  0.6

# %%
zeroshot_results['Answer'][1] == float(zeroshot_results['Predicted'][1])
# Out:
# True

# %%
zeroshot_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Question    10 non-null     object
#  1   Answer      10 non-null     float64
#  2   Operator    10 non-null     object
#  3   Num_Digits  10 non-null     object
#  4   Predicted   10 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 532.0+ bytes

# %%
chatgpt_completion("GIVE ME ONLY THE RESULT IN ONE WORD" + dataset.loc[0]['Operation'])
# Out:
# '8871'

# %%
len(data_list)
# Out:
# 3048

# %%
results3 = pd.DataFrame(data_list)

# %%
# getting accuracy metrics
evaluate(results3['Predicted'], 
         results3['Answer'])
# Out:
# The scores on the test set:  0.45898950131233596

# %%
zeroshot_results = results3.copy()

# %%
 # getting subset of results where number of digits is 3
zeroshot_results_3 = zeroshot_results[zeroshot_results['Num_Digits'] == "Three digits"]

# getting subset of results where number of digits is 4
zeroshot_results_4 = zeroshot_results[zeroshot_results['Num_Digits'] == "Four digits"]

# getting subset of results where number of digits is 5
zeroshot_results_5 = zeroshot_results[zeroshot_results['Num_Digits'] == "Five digits"]

# %%
# evaluation of the results for number of digits 3
print("Three digits result", zeroshot_results_3.Correct.sum()/len(zeroshot_results_3))

# evaluation of the results for number of digits 4
print("Four digits result", zeroshot_results_4.Correct.sum()/len(zeroshot_results_4))

# evaluation of the results for number of digits 5
print("Five digits result", zeroshot_results_5.Correct.sum()/len(zeroshot_results_5))
# Out:
# Three digits result 0.4662813102119461
# Four digits result 0.465832531280077
# Five digits result 0.44387229660144184

# %%
# getting subset of results where operator is addition
zeroshot_results_add = zeroshot_results[zeroshot_results['Operator'] == "addition"]

# getting subset of results where operator is subtraction
zeroshot_results_sub = zeroshot_results[zeroshot_results['Operator'] == "subtraction"]

# getting subset of results where operator is multiplication
zeroshot_results_mul = zeroshot_results[zeroshot_results['Operator'] == "multiplication"]

# getting subset of results where operator is division
zeroshot_results_div = zeroshot_results[zeroshot_results['Operator'] == "division"]

# %%
# evaluation of the results for addition
print("Addition result", zeroshot_results_add.Correct.sum()/len(zeroshot_results_add))

# evaluation of the results for subtraction
print("Subtraction result", zeroshot_results_sub.Correct.sum()/len(zeroshot_results_sub))

# evaluation of the results for multiplication
print("Multiplication result", zeroshot_results_mul.Correct.sum()/len(zeroshot_results_mul))

# evaluation of the results for division
print("Division result", zeroshot_results_div.Correct.sum()/len(zeroshot_results_div))
# Out:
# Addition result 0.974293059125964
# Subtraction result 0.8403693931398417
# Multiplication result 0.005369127516778523
# Division result 0.0

# %%
# round off the answer to 2 decimal places
zeroshot_results['Answer'] = zeroshot_results['Answer'].apply(lambda x: round(float(x), 2))

# %%
zeroshot_results_div2 = zeroshot_results_div.copy()
zeroshot_results_div2['Correct'] = zeroshot_results_div2.apply(lambda x: 1 if round(float(x['Predicted']), 2) == round(float(x['Answer']), 2) else 0, axis=1)
zeroshot_results_div2['Correct'].sum()/len(zeroshot_results_div)
# Out:
# 0.5045632333767927

# %%
zeroshot_results_div2['Correct'] = zeroshot_results_div2.apply(lambda x: 1 if round(float(x['Predicted']), 3) == round(float(x['Answer']), 3) else 0, axis=1)
zeroshot_results_div2['Correct'].sum()/len(zeroshot_results_div)
# Out:
# 0.22816166883963493

# %%
zeroshot_results_div2['Correct'] = zeroshot_results_div2.apply(lambda x: 1 if round(float(x['Predicted']), 4) == round(float(x['Answer']), 4) else 0, axis=1)
zeroshot_results_div2['Correct'].sum()/len(zeroshot_results_div)
# Out:
# 0.03911342894393742

# %%
zeroshot_results_div2 = zeroshot_results_div.copy()
zeroshot_results_div2['Correct'] = zeroshot_results_div2.apply(lambda x: 1 if round(float(x['Predicted']), 1) == round(float(x['Answer']), 1) else 0, axis=1)
zeroshot_results_div2['Correct'].sum()/len(zeroshot_results_div)
# Out:
# 0.6049543676662321
